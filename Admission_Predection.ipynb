# %% [markdown]
# # **Admission Predection**

# %%
# Importing the libraries
import pandas as pd
import numpy as np
import matplotlib as plt
import tensorflow as tf

# %%
# reading the data
df=pd.read_csv('Admission_Predict.csv')

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %% [markdown]
# Columns Informations
# -->GRE Scores ( out of 340 )
# -->TOEFL Scores ( out of 120 )
# -->University Rating ( out of 5 )
# -->Statement of Purpose and Letter of Recommendation Strength ( out of 5 )
# -->Undergraduate GPA ( out of 10 )
# -->Research Experience ( either 0 or 1 )
# -->Chance of Admit ( ranging from 0 to 1 )

# %%
#Dimension of the data
df.shape
# Out:
# (400, 9)

# %%
# checking the information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.3 KB

# %%
# checking the discription
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
# checking for the null values
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
# checking for thr duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# --> From the above data we dont have any null values
# --> No duplicates
# -->Data types are perfect

# %%
# removing the un wanted columns
df.drop('Serial No.',axis=1,inplace=True)

# %%
df
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Chance of Admit
# 0                0.92
# 1                0.76
# ...

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
# splitting the data into the dependent and the independent
x=df.drop('Chance of Admit ',axis=1)
y=df['Chance of Admit ']

# %%
# scaling the data
scaler = MinMaxScaler()

# %%
#splitting the data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_test.shape
# Out:
# (80, 7)

# %%
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
# saving in the variable
model=Sequential()

# %%
# creating the multilayer percrptron
model.add(Dense(7,activation='relu',input_dim=7))
model.add(Dense(7,activation='relu'))
model.add(Dense(5,activation='relu'))
model.add(Dense(1,activation='linear'))

# %%
#summary
model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_25 (Dense)                │ (None, 7)              │            56 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 7)              │            56 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 5)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 158 (632.00 B)
#  Trainable params: 158 (632.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# compaling the model
model.compile(optimizer='adam',loss='mse')

# %%
#fitting the model with the 100 epochs
model.fit(x_train_scaled,y_train,epochs=110,validation_split=0.2)
# Out:
# Epoch 1/110
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0040 - val_loss: 0.0044
# Epoch 2/110
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0040 - val_loss: 0.0044
# Epoch 3/110
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0038 - val_loss: 0.0044
# Epoch 4/110
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0042 - val_loss: 0.0044
# Epoch 5/110
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 6/110
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0036 - val_loss: 0.0044
# Epoch 7/110
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0036 - val_loss: 0.0044
# Epoch 8/110
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0037 - val_loss: 0.0044
# Epoch 9/110
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0037 - val_loss: 0.0043
# Epoch 10/110
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0038 - val_loss: 0.0044
# Epoch 11/110
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 12/110
# ...

# %%
model.layers[0].get_weights()
# Out:
# [array([[ 0.39440012,  0.23774882,  0.02671057,  0.5417403 , -0.658543  ,
#           0.5194489 ,  0.25708014],
#         [-0.5311319 ,  0.62196624, -0.38723326, -0.48754644,  0.4890595 ,
#           0.38543966,  0.20296288],
#         [ 0.07006848, -0.289838  , -0.14203583,  0.6508504 ,  0.46584195,
#           0.07965234,  0.350673  ],
#         [-0.55922925,  0.7172973 , -0.5163134 , -0.23137188,  0.37805906,
#           0.01534029, -0.04385521],
#         [-0.08471127,  0.48679242, -0.20719315, -0.27128682,  0.07698529,
#          -0.00204312, -0.3694407 ],
#         [-0.03364079, -0.4038072 ,  0.02335957,  0.47187218, -0.10996626,
#           0.5111011 , -0.2455983 ],
#         [-0.5596034 , -0.43716332,  0.63254243,  0.0838464 ,  0.64727646,
#          -0.2645915 , -0.58620405]], dtype=float32),
#  array([-0.03127467,  0.15594766,  0.09216766,  0.13736887, -0.03169574,
#         -0.03683864,  0.0124165 ], dtype=float32)]

# %%
y_prob=model.predict(x_test_scaled)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
from sklearn.metrics import r2_score
round(r2_score(y_test,y_prob),4)
# Out:
# 0.7993
